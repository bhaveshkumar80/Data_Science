# %%
import dash
from dash.dependencies import Input, Output 
import dash_core_components as dcc
import dash_html_components as html

# %%
app = dash.Dash()

app.layout = html.Div([
    dcc.Input(id='input', value='Enter Something Here!', type='text'),
    html.Div(id='output')
])

@app.callback(
    Output(component_id='output', component_property='children'),
    [Input(component_id='input', component_property='value')]
)
def update_value(input_data):
    try:
        return str(float(input_data) ** 2)
    except:
        return "Some Error"

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [30/Dec/2020 16:00:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:31] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:31] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:00:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
import datetime
import pandas_datareader.data as web

start = datetime.datetime(2015, 1, 1)
end = datetime.datetime.now()
df = web.DataReader("TSLA", 'yahoo', start, end)
df.reset_index(inplace=True)
df.set_index("Date", inplace=True)
#df = df.drop('Symbol', axis=1)

df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2014-12-31  45.136002  44.450001  44.618000  44.481998  11487500.0  44.481998
# 2015-01-02  44.650002  42.652000  44.574001  43.862000  23822000.0  43.862000
# 2015-01-05  43.299999  41.431999  42.910000  42.018002  26842500.0  42.018002
# 2015-01-06  42.840000  40.841999  42.012001  42.256001  31309500.0  42.256001
# 2015-01-07  42.956001  41.956001  42.669998  42.189999  14842000.0  42.189999

# %%
app = dash.Dash()
stock = 'TSLA'

app.layout = html.Div(children=[
    html.H1(children='whao, a graph!'),
    
    html.Div(children='Making a stock graph!'),
    
    dcc.Graph(
        id='example-graph',
        figure={
            'data': [
                {'x': df.index, 'y': df.Close, 'type': 'line', 'name': stock}
            ],
            'layout': {
                'title': stock
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [30/Dec/2020 16:51:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:51:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 16:51:32] "GET /_dash-layout HTTP/1.1" 200 -

# %%
app = dash.Dash()

app.layout = html.Div([
    dcc.Input(id='input', value='', type='text'),
    html.Div(id='output-graph')
])

@app.callback(
    Output(component_id='output-graph', component_property='children'),
    [Input(component_id='input', component_property='value')]
)

def update_value(input_data):
    start = datetime.datetime(2015, 1, 1)
    end = datetime.datetime.now()
    df = web.DataReader(input_data, 'yahoo', start, end)
    df.reset_index(inplace=True)
    df.set_index("Date", inplace=True)
    
    return dcc.Graph(
        id='example-graph',
        figure={
            'data': [
                {'x': df.index, 'y': df.Close, 'type': 'line', 'name': input_data},
            ],
            'layout': {
                'title': input_data
            }
        }
    )

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [30/Dec/2020 17:01:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:01:10] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:01:10] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420065000&period2=1609367399&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420065000&period2=1609367399&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420065000&period2=1609367399&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420065000&period2=1609367399&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420065000%26period2%3d1609367399%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [30/Dec/2020 17:01:17] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [30/Dec/2020 17:01:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:02:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:02:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:02:23] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aak using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aak using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aak using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aak using YahooDailyReader
# 127.0.0.1 - - [30/Dec/2020 17:02:33] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [30/Dec/2020 17:02:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:02:54] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aall using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aall using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aall using YahooDailyReader
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-12-3b4d4049aca1>", line 16, in update_value
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\util\_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\data.py", line 384, in DataReader
#     session=session,
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "C:\Users\Bhavesh kumar\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas_datareader\yahoo\daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol aall using YahooDailyReader
# 127.0.0.1 - - [30/Dec/2020 17:03:07] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [30/Dec/2020 17:03:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Dec/2020 17:03:23] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
import dash
from dash.dependencies import Output, Input
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import random
from collections import deque

X = deque(maxlen=20)
X.append(1)
Y = deque(maxlen=20)
Y.append(1)

app = dash.Dash(__name__)
app.layout = html.Div([
    dcc.Graph(id='live-graph', animate=True),
    dcc.Interval(id='graph-update', interval = 1*1000),
])

@app.callback(Output('live-graph', 'figure'),
             [Input('graph-update', 'n_intervals')])

def update_graph_scatter(input_data):
    X.append(X[-1] + 1)
    Y.append(Y[-1] + Y[-1] * random.uniform(-0.1, 0.1))
    
    data = go.Scatter(x=list(X), y=list(Y), name='Scatter',
                     mode='lines+markers')
    
    return {'data': [data], 'layout': go.Layout(xaxis=dict(range=[min(X), max(X)]),
                                               yaxis=dict(range=[min(Y), max(Y)]))}

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/Dec/2020 11:14:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:14:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:15:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:16:15] "POST /_dash-update-component HTTP/1.1" 200 -
